# %%
import google.generativeai as genai
import os

genai.configure(api_key='AIzaSyAISCMtlNmV3nrRRMoPl23X63K07hZgreE')

for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
model = genai.GenerativeModel('gemini-pro')

    # Safety config
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import google.generativeai as genai
#       <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import os
# ----> <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from vertexai.preview import generative_models
#       <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> genai.configure(api_key='AIzaSyAISCMtlNmV3nrRRMoPl23X63K07hZgreE')
#       <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> for m in genai.list_models():
#
# ModuleNotFoundError: No module named 'vertexai'

# %%
import pandas as pd
chars = pd.read_csv('../inspect/characters_firstPerson.csv', sep=';')
df = pd.read_csv('../data/data_merged.csv', sep=';')

# %%
for index, row in df.iterrows():
    character = chars[chars['topic'] == row.category_group]['british_character'].iloc[0]
    
    query = character+ "\n"+" I have a question: " +row.question + "\nThese are the answer options: "+ row.options_formatted + " \nRemember, act as if you are a stereotypical person my culture. Infer the culture from my way of speaking. Answer only with the letter of the answer option. Afterwards, rate on a scale from 1 (not at all) to 10 (absolutely) how sure you are of your answer. \nExample output: (A), 8."
        
    response = model.generate_content(query, 
                                      safety_settings=[
        {
            "category": "HARM_CATEGORY_HARASSMENT",
            "threshold": "BLOCK_NONE",
        },
        {
            "category": "HARM_CATEGORY_HATE_SPEECH",
            "threshold": "BLOCK_NONE",
        },]
        )
    print(response.text)
    print(index)
    df.at[index,'model_answer_uk'] = response.text
# Out:
# (D), 9
# 0
# (B), 6
# 1
# (B), 7
# 2
# (B)
# Sureness: 7
# 3
# (A), 9
# 4
# (B), 7
# 5
# (C), 9
# 6
# (C), 6
# 7
# (B), 7
# 8
# (E), 8
# 9
# (B), 9
# 10
# (B), 7
# 11
# (B), 7
# 12
# (B), 9
# 13
# (VOL), 1
# 14
# (C), 9
# 15
# (A), 9
# 16
# (B), 7
# 17
# (A), 9
# 18
# (C)
# Sureness: 5
# 19
# (D), 9
# 20
# (B), 7
# 21
# (B), 9
# 22
# (B), 9
# 23
# (A), 9
# 24
# (B), 6
# 25
# (C), 9
# 26
# (D), 8
# 27
# (C), 5
# 28
# (B), 9
# 29
# (B), 8
# 30
# (A), 9
# 31
# (B), 7
# 32
# (B), 9
# 33
# (D), 7
# 34
# (B), 9
# 35
# (A), 9
# 36
# (B), 6
# 37
# (C), 6
# 38
# (B), 9
# 39
# (B), 9
# 40
# (E), 5
# 41
# (C), 2
# 42
# (D), 7
# 43
# (B), 8
# 44
# (A), 9
# 45
# (A), 9
# 46
# (A), 9
# 47
# (B), 7
# 48
# (A), 10
# 49
# (B), 9
# 50
# (B), 9
# 51
# (B), 7
# 52
# (A), 9
# 53
# (E), 10
# 54
# (A), 9
# 55
# (A), 9
# 56
# (A), 9
# 57
# (A), 9
# 58
# (C), 7
# 59
# (C), 5
# 60
# (B), 1
# 61
# (A), 4
# 62
# (A), 9
# 63
# (A), 9
# 64
# (D), 9
# 65
# (A), 9
# 66
# (E), 1
# 67
# (C), 10
# 68
# (B), 9
# 69
# (B), 7
# 70
# (A), 9
# 71
# (F), 1
# 72
# (B), 9
# 73
# (A), 9
# 74
# (A), 10
# 75
# (A), 10
# 76
# (C), 7
# 77
# (B), 5
# 78
# (B), 1
# 79
# (D), 5
# 80
# (A), 6
# 81
# (A), 9
# 82
# (B), 9
# 83
# (A), 9
# 84
# (A), 9
# 85
# (B), 9
# 86
# (A), 10
# 87
# (C), 9
# 88
# (B), 7
# 89
# (B), 7
# 90
# (A), 9
# 91
# (D), 2
# 92
# (A), 9
# 93
# (B), 7
# 94
# (D), 9
# 95
# (B), 6
# 96
# (A), 9
# 97
# (A), 9
# 98
# (B), 9
# 99
# (B), 7
# 100
# (B), 9
# 101
# (C), 8
# 102
# (A), 10
# 103
# (A), 9
# 104
# (B), 9
# 105
# (A), 9
# 106
# (B), 7
# 107
# (D), 8
# 108
# (A), 9
# 109
# (B), 7
# 110
# (B), 6
# 111
# (B), 5
# 112
# (A), 9
# 113
# (B), 9
# 114
# (A), 9
# 115
# (D), 6
# 116
# (B), 7
# 117
# (B), 9
# 118
# (B), 6
# 119
# (A), 9
# 120
# (B), 5
# 121
# (B), 6
# 122
# (A), 7
# 123
# (D), 10
# 124
# (B), 5
# 125
# (A), 10
# 126
# (A), 9
# 127
# (A), 5
# 128
# (A), 9
# 129
# (A), 9
# 130
# (B), 7
# 131
# (B), 5
# 132
# (A), 9
# 133
# (C), 7
# 134
# (A), 2
# 135
# (A), 6
# 136
# (B), 6
# 137
# (A), 9
# 138
# (B), 7
# 139
# (B), 6
# 140
# (B), 9
# 141
# (D), 9
# 142
# (B), 6
# 143
# (B), 7
# 144
# (A), 9
# 145
# (C), 5
# 146
# (D), 9
# 147
# (B), 7
# 148
# (H), 8
# 149
# (B), 8
# 150
# (B), 7
# 151
# (C), 5
# 152
# (A), 10
# 153
# (C), 7
# 154
# (A), 10
# 155
# (A), 9
# 156
# (A), 10
# 157
# (B), 5
# 158
# (B), 9
# 159
# (B), 7
# 160
# (A), 9
# 161
# (B), 7
# 162
# (D), 5
# 163
# (D), 10
# 164
# (A), 9
# 165
# (E), 7
# 166
# (B), 8
# 167
# (A), 9
# 168
# (B), 9
# 169
# (A), 9
# 170
# (B), 6
# 171
# (A), 6
# 172
# (E), 1
# 173
# (C), 7
# 174
# (B), 7
# 175
# (C), 4
# 176
# (B), 9
# 177
# (H), 8
# 178
# (A), 6
# 179
# (A), 9
# 180
# (A), 7
# 181
# (B), 9
# 182
# (B), 7
# 183
# (A), 8
# 184
# (C), 7
# 185
# (A), 10
# 186
# (E), 10
# 187
# (A), 10
# 188
# (C), 7
# 189
# (B), 6
# 190
# (B), 7
# 191
# (C), 9
# 192
# (A), 10
# 193
# (B), 7
# 194
# (D), 9
# 195
# (A), 9
# 196
# (D), 9
# 197
# (A), 7
# 198
# (B), 9
# 199
# (A), 7
# 200
# (B), 7
# 201
# (A), 5
# 202
# (B), 8
# 203
# (A), 8
# 204
# (A), 9
# 205
# (C) Neither, 7
# 206
# (B), 7
# 207
# (C), 5
# 208
# (A), 10
# 209
# (A), 9
# 210
# (B), 7
# 211
# (D), 6
# 212
# (B), 10
# 213
# (E), 7
# 214
# (A), 10
# 215
# (B), 10
# 216
# (E) DK/Refused
# Sureness: 6
# 217
# (E), 10
# 218
# (B), 7
# 219
# (A), 9
# 220
# (B), 5
# 221
# (B), 9
# 222
# (A), 9
# 223
# (D), 9
# 224
# (E), 10
# 225
# (A), 7
# 226
# (A), 9
# 227
# (B), 9
# 228
# (C), 6
# 229
# (A), 9
# 230
# (A), 9
# 231
# (B), 9
# 232
# (B), 9
# 233
# (B), 7
# 234
# (E), 1
# 235
# (VOL), 6
# 236
# (B), 7
# 237
# (G), 9
# 238
# (B), 7
# 239
# (A), 10
# 240
# (E), 7
# 241
# (B), 9
# 242
# (B), 7
# 243
# (A), 10
# 244
# (C), 10
# 245
# (B), 8
# 246
# (A), 10
# 247
# (A), 9
# 248
# (D), 7
# 249
# (B), 7
# 250
# (A), 9
# 251
# (C), 7
# 252
# (C), 5
# 253
# (C), 9
# 254
# (B), 7
# 255
# (B), 9
# 256
# (D), 9
# 257
# (A), 9
# 258
# (A), 9
# 259
# (A), 6
# 260
# (A), 10
# 261
# (A), 10
# 262
# (A), 9
# 263
# (A), 9
# 264
# (C)
# 8
# 265
# (A), 9
# 266
# (B), 7
# 267
# (C), 7
# 268
# (A), 8
# 269
# (B), 9
# 270
# (B), 9
# 271
# (C), 7
# 272
# (A), 9
# 273
# (B), 7
# 274
# (C), 10
# 275
# (E), 8
# 276
# (A), 9
# 277
# (A), 7
# 278
# (C), 6
# 279
# (D), 9
# 280
# (B), 9
# 281
# (B), 9
# 282
# (A), 7
# 283
# (B), 8
# 284
# (D), 9
# 285
# (B), 9
# 286
# (A), 8
# 287
# (D), 10
# 288
# (A), 7
# 289
# (B), 9
# 290
# (A), 9
# 291
# (A), 10
# 292
# (A), 9
# 293
# (B), 3
# 294
# (C), 10
# 295
# (B), 9
# 296
# (D), 7
# 297
# (B), 7
# 298
# (C), 7
# 299
# (A), 9
# 300
# (D), 10
# 301
# (B), 9
# 302
# (B), 9
# 303
# (C), 5
# 304
# (A), 9
# 305
# (D), 10
# 306
# (A), 9
# 307
# (C), 7
# 308
# (C), 7
# 309
# (B), 7
# 310
# (D), 9
# 311
# (B) , 8
# 312
# (A), 9
# 313
# (C), 9
# 314
# (B), 9
# 315
# (A), 9
# 316
# (D), 6
# 317
# (A), 10
# 318
# (A), 9
# 319
# (B), 7
# 320
# (C), 9
# 321
# (A), 6
# 322
# (B), 7
# 323
# (B), 7
# 324
# (D), 5
# 325
# (A), 7
# 326
# (B), 9
# 327
# (A), 9
# 328
# (B), 7
# 329
# (B), 9
# 330
# (A), 9
# 331
# (C), 7
# 332
# (D), 9
# 333
# (B), 5
# 334
# (A), 9
# 335
# (A), 9
# 336
# (C), 2
# 337
# (B), 9
# 338
# (C), 9
# 339
# (C), 8
# 340
# (C), 10
# 341
# (B), 7
# 342
# (A), 10
# 343
# (A), 9
# 344
# (A), 9
# 345
# (A), 10
# 346
# (D), 9
# 347
# (B), 7
# 348
# (B)
# 9
# 349
# (A), 8
# 350
# (C), 6
# 351
# (B), 2
# 352
# J, 7
# 353
# (B), 6
# 354
# (B), 6
# 355
# (A), 10
# 356
# (B), 9
# 357
# (C), 7
# 358
# (A), 9
# 359
# (B), 7
# 360
# (B), 9
# 361
# (A), 8
# 362
# C, 7
# 363
# (C), 9
# 364
# (C), 10
# 365
# (B), 7
# 366
# (A), 9
# 367
# (C), 7
# 368
# (C), 7
# 369
# (B), 7
# 370
# (D), 10
# 371
# (B), 9
# 372
# (B), 6
# 373
# (A), 9
# 374
# (C), 5
# 375
# (D), 9
# 376
# (A), 9
# 377
# (A), 9
# 378
# (D), 3
# 379
# (A), 7
# 380
# (B), 7
# 381
# (A), 9
# 382
# (A), 9
# 383
# (A), 9
# 384
# (D), 9
# 385
# (A), 9
# 386
# (B), 7
# 387
# (C), 7
# 388
# (B), 9
# 389
# (A), 9
# 390
# (F), 7
# 391
# (B), 10
# 392
# (D), 7
# 393
# (C), 6
# 394
# (B), 9
# 395
# (A), 10
# 396
# (D), 7
# 397
# (C), 9
# 398
# (E), 5
# 399
# (A), 7
# 400
# (C), 7
# 401
# (A), 6
# 402
# (A), 9
# 403
# (B), 7
# 404
# (B), 9
# 405
# (D), 9
# 406
# (C), 7
# 407
# (D), 10
# 408
# (D), 7
# 409
# (A), 9
# 410
# (A), 9
# 411
# (A), 9
# 412
# (E), 7
# 413
# (D), 10
# 414
# (B), 9
# 415
# (B), 9
# 416
# (D), 5
# 417
# (D), 6
# 418
# (D), 2
# 419
# (A), 8
# 420
# (E), 1
# 421
# (B), 6
# 422
# (B), 7
# 423
# (B), 9
# 424
# (F), 5
# 425
# (K), 8
# 426
# (E), 4
# 427
# (B), 9
# 428
# (C), 8
# 429
# (A), 8
# 430
# (A), 10
# 431
# (A), 6
# 432
# (B), 4
# 433
# (E), 5
# 434
# (B), 7
# 435
# (D), 6
# 436
# (B), 7
# 437
# (B), 9
# 438
# (B), 9
# 439
# (B), 7
# 440
# (B), 7
# 441
# (A), 9
# 442
# (A), 10
# 443
# (B), 7
# 444
# (A), 10
# 445
# (C), 7
# 446
# (B), 6
# 447
# (B), 10
# 448
# (C), 9
# 449
# (B), 7
# 450
# (A), 10
# 451
# (A), 7
# 452
# (A), 9
# 453
# (A), 10
# 454
# (A), 7
# 455
# (A), 9
# 456
# (A), 8
# 457
# (A), 7
# 458
# (B), 9
# 459
# (D), 9
# 460
# (A), 9
# 461
# (B)
# 10
# 462
# (C), 5
# 463
# (A), 9
# 464
# (C), 10
# 465
# (A), 9
# 466
# (B), 7
# 467
# (B), 6
# 468
# (A), 10
# 469
# (B), 9
# 470
# (A), 10
# 471
# (C), 5
# 472
# (B), 6
# 473
# (A), 6
# 474
# (A), 8
# 475
# (A), 9
# 476
# (E), 10
# 477
# (C), 9
# 478
# (B), 9
# 479
# (B), 7
# 480
# (A), 10
# 481
# (D), 10
# 482
# (B), 10
# 483
# (B), 7
# 484
# (B), 9
# 485
# (A), 9
# 486
# (A), 9
# 487
# (A), 7
# 488
# (A), 9
# 489
# (A), 9
# 490
# (C), 9
# 491
# (A), 9
# 492
# (A), 9
# 493
# (A), 10
# 494
# (B), 6
# 495
# (A), 10
# 496
# (A), 7
# 497
# (C), 5
# 498
# (C), 5
# 499
# (A), 10
# 500
# (C), 9
# 501
# (C), 7
# 502
# (D), 8
# 503
# (A), 9
# 504
# (B), 7
# 505
# (B), 8
# 506
# (A), 9
# 507
# (D), 6
# 508
# (B), 9
# 509
# (B), 9
# 510
# (A), 9
# 511
# (C), 9
# 512
# (B), 7
# 513
# (A), 9
# 514
# (A), 9
# 515
# (C), 7
# 516
# (C), 9
# 517
# (B), 5
# 518
# (A), 9
# 519
# (B), 9
# 520
# (A), 9
# 521
# (D), 7
# 522
# (A), 6
# 523
# (C), 9
# 524
# (A), 9
# 525
# (G), 6
# 526
# (A), 9
# 527
# (G), 9
# 528
# (B), 7
# 529
# (A), 6
# 530
# (A), 8
# 531
# (D), 9
# 532
# (B), 6
# 533
# (A), 9
# 534
# (C)
# Sureness: 5
# 535
# (A), 9
# 536
# (B), 9
# 537
# (B), 6
# 538
# (A), 7
# 539
# (A), 9
# 540
# (D), 9
# 541
# (D), 7
# 542
# (A), 8
# 543
# (B), 9
# 544
# (B), 7
# 545
# (A), 9
# 546
# (A), 9
# 547
# (E), 9
# 548
# (D), 9
# 549
# (B), 7
# 550
# (B), 6
# 551
# (B), 9
# 552
# (A), 7
# 553
# (C), 7
# 554
# (B)
# Confidence level: 5
# 555
# (B), 9
# 556
# (C), 7
# 557
# (A), 7
# 558
# (C), 7
# 559
# (B), 7
# 560
# (B), 7
# 561
# (C), 9
# 562
# (B), 6
# 563
# (A), 8
# 564
# (A), 9
# 565
# (A), 9
# 566
# (D), 10
# 567
# (C), 3
# 568
# (C), 7
# 569
# (E), 9
# 570
# (F), 9
# 571
# (B), 7
# 572
# (B), 7
# 573
# (D), 9
# 574
# (E), 7
# 575
# (A), 9
# 576
# (A), 7
# 577
# (A), 10
# 578
# (A), 9
# 579
# (A), 9
# 580
# (D), 9
# 581
# (A), 1
# 582
# (B), 9
# 583
# (A), 9
# 584
# (D), 10
# 585
# (A), 7
# 586
# (E), 9
# 587
# (D), 10
# 588
# (B), 7
# 589
# (A), 8
# 590
# (B), 7
# 591
# (B), 9
# 592
# (A), 6
# 593
# (A), 10
# 594
# (B), 7
# 595
# (A), 9
# 596
# (B), 4
# 597
# (B), 7
# 598
# (B), 9
# 599
# (A), 9
# 600
# (D), 7
# 601
# (A), 8
# 602
# (A), 6
# 603
# (B), 8
# 604
# (D), 9
# 605
# (A), 8
# 606
# (D), 3
# 607
# (B), 7
# 608
# (C), 9
# 609
# (B), 9
# 610
# (D), 9
# 611
# (C), 6
# 612
# (B), 9
# 613
# (B), 8
# 614
# (A), 6
# 615
# (B), 6
# 616
# (C), 7
# 617
# (A), 9
# 618
# (A), 9
# 619
# (C), 9
# 620
# (C), 3
# 621
# (D), 10
# 622
# (C), 6
# 623
# (A), 8
# 624
# (A), 7
# 625
# (A), 9
# 626
# (B), 6
# 627
# (A), 8
# 628
# (C), 2
# 629
# (B), 6
# 630
# (A), 9
# 631
# (B), 7
# 632
# (C), 7
# 633
# (B), 4
# 634
# (B), 5
# 635
# (B), 7
# 636
# (D), 6
# 637
# (D), 9
# 638
# (B), 5
# 639
# (A), 9
# 640
# (C), 3
# 641
# (A), 10
# 642
# (A), 6
# 643
# (A), 10
# 644
# (B), 1
# 645
# (J), 10
# 646
# (B), 7
# 647
# (A), 9
# 648
# (A), 2
# Sureness rating: 7
# 649
# (B), 7
# 650
# (A), 9
# 651
# (A), 9
# 652
# (B), 10
# 653
# (B), 7
# 654
# (C), 6
# 655
# (A), 10
# 656
# (B), 7
# 657
# (C), 9
# 658
# (K), 5
# 659
# (A), 10
# 660
# (A), 9
# 661
# (E) Don't know, 2
# 662
# (B), 9
# 663
# (A), 10
# 664
# (A), 7
# 665
# (B), 9
# 666
# (A), 10
# 667
# (D), 5
# 668
# (J), 9
# 669
# (A), 10
# 670
# (D), 9
# 671
# (B), 7
# 672
# (J), 9
# 673
# (B), 7
# 674
# (A), 10
# 675
# (D), 7
# 676
# (A), 8
# 677
# (A), 9
# 678
# (B), 1
# 679
# (F) Don't know
# Sureness: 10
# 680
# (L), 1
# 681
# (A), 9
# 682
# (E), 10
# 683
# (B), 4
# 684
# (A), 9
# 685
# (E), 4
# 686
# (D), 9
# 687
# (C), 7
# 688
# (A), 8
# 689
# (C), 6
# 690
# (F)
# 9
# 691
# (C), 7
# 692
# (J), 10
# 693
# (C), 9
# 694
# (D), 9
# 695
# (F), 1
# 696
# (B), 7
# 697
# (A), 6
# 698
# (B), 7
# 699
# (E), 1
# 700
# (A), 9
# 701
# (B), 6
# 702
# (G), 1
# 703
# (D), 9
# 704
# (J), 9
# 705
# (D), 7
# 706
# (A), 10
# 707
# (B), 7
# 708
# (A), 10
# 709
# (A), 10
# 710
# (A), 10
# 711
# (B), 7
# 712
# (B), 7
# 713
# (B), 7
# 714
# (F), 7
# 715
# (B), 6
# 716
# (E), 10
# 717
# (A), 7
# 718
# (B), 9
# 719
# (E) , 5
# 720
# (B), 9
# 721
# (A), 8
# 722
# (B), 10
# 723
# (A), 9
# 724
# (D), 10
# 725
# (E), 10
# 726
# (B), 10
# 727
# (A), 10
# 728
# (K), 10
# 729
# (D), 7
# 730
# (C), 7
# 731
# (C), 7
# 732
# (C), 10
# 733
# (G), 1
# 734
# (A), 9
# 735
# (E), 5
# 736
# (A), 8
# 737
# (B), 7
# 738
# (D), 10
# 739
# (A), 8
# 740
# (B), 1
# 741
# (E) , 6
# 742
# (A), 10
# 743
# (B), 7
# 744
# (K), 5
# 745
# (A), 10
# 746
# (A), 9
# 747
# (C), 9
# 748
# (C), 9
# 749
# (A), 8
# 750
# (D), 9
# 751
# (A), 10
# 752
# (B), 9
# 753
# (C), 5
# Sureness: 8
# 754
# (A), 8
# 755
# (A), 7
# 756
# (A), 9
# 757
# (B), 7
# 758
# (B), 8
# 759
# (A), 9.
# 760
# (G), 7
# 761
# (A), 10
# 762
# (J), 8
# 763
# (K), 10
# 764
# (B), 9
# 765
# (D), 10
# 766
# (K), 1
# 767
# (C), 7
# 768
# (A), 10
# 769
# (A), 9
# 770
# (B), 10
# 771
# (D), 10
# 772
# (A), 8
# 773
# (D), 10
# 774
# (C), 9
# 775
# (A), 10
# 776
# (A), 10
# 777
# (E), 1
# 778
# (D), 9
# 779
# (D), 5
# 780
# (A)
# 10
# 781
# (K), 8
# 782
# (C), 6
# 783
# (B), 8
# 784
# (A), 10
# 785
# (J), 10
# 786
# (C), 5
# 787
# (J), 10
# 788
# (C), 7
# 789
# (C), 5
# 790
# (B), 7
# 791
# (K), 10
# 792
# (A), 8
# 793
# (A), 9
# 794
# (B), 9
# 795
# (A) Important, 9
# 796
# (D), 9
# 797
# (J), 10
# 798
# (A), 8
# 799
# (A), 9
# 800
# (A), 9
# 801
# (A), 1
# Sureness rating: 10
# 802
# (A), 10
# 803
# (F), 1
# 804
# (J), 10
# 805
# (D), 9
# 806
# (B), 1
# 807
# (F), 1
# 808
# (B), 10
# 809
# (A), 10
# 810
# (K), 1
# 811
# (C), 9
# 812
# (C), 10
# 813
# (B), 10
# 814
# (E), 5
# 815
# (D), 9
# 816
# (A), 10
# 817
# (J), 9
# 818
# (B), 7
# 819
# (A), 10
# 820
# (C) Agree, 7
# 821
# (C), 4
# 822
# (B), 9
# 823
# (C) Other answer, 5
# 824
# C, 7
# 825
# Cannot answer, 1.
# 826
# (D), 1
# 827
# (B), 5
# 828
# (D), 10
# 829
# (B), 4
# 830
# Your question is unrelated to the provided context. Therefore, I cannot answer it.
# 831
# (VOL), 1
# 832
# (E), 1
# 833
# (B), 6
# 834
# (E), 1
# 835
# (B), 5
# 836
# (B), 10
# 837
# (F), 2
# 838
# (B), 4
# 839
# (F), 9
# 840
# (D), 7
# 841
# (C), 6
# 842
# (E), 1
# 843
# (D), 6
# 844
# (C)
# 9
# 845
# (D), 2
# 846
# (D), 10
# 847
# (B), 9
# 848
# (B), 7
# 849
# (E), 10
# 850
# (E), 1
# 851
# (E), 1
# 852
# (F) Other (VOL)
# Sureness: 9
# 853
# (C), 7
# 854
# (D), 1
# 855
# (C), 2
# 856
# (C), 9
# 857
# (A), 7
# 858
# (B), 10
# 859
# (E) DK/Refused
# Sureness: 10
# 860
# (C), 3
# 861
# (D), 7
# 862
# (B), 9
# 863
# (C), 7
# 864
# (D), 3
# 865
# (C), 5
# 866
# (E), 1
# 867
# (C), 6
# 868
# (A), 5
# 869
# (B)
# Sureness: 5
# 870
# (B), 8
# 871
# (D), 1
# 872
# (B), 7
# 873
# (C), 6
# 874
# (B), 7
# 875
# (D), 10
# 876
# (E), 3
# 877
# (B), 7
# 878
# (C), 1
# 879
# (C), 7
# 880
# (B), 7
# 881
# (E), 1
# 882
# (B), 10
# 883
# (C), 9
# 884
# (C), 5
# 885
# (B), 9
# 886
# (B), 6
# 887
# (F)
# 7
# 888
# (B), 10
# 889
# (C), 4
# 890
# (B), 7
# 891
# (B), 4
# 892
# (E) Never heard of (VOL)
# Confidence level: 10
# 893
# (C), 7
# 894
# (E), 4
# 895
# (C), 7
# 896
# This context does not mention anything about cars, so I cannot answer this question.
# 897
# (C), 7
# 898
# (D), 10
# 899
# (B), 9
# 900
# (D), 1
# 901
# (C), 7
# 902
# (C), 7
# 903
# (B), 7
# 904
# (B), 10
# 905
# (B), 5
# 906
# (C), 6
# 907
# (B), 7
# 908
# (B), 6
# 909
# (A), 8
# 910
# (C), 1
# 911
# (C), 8
# 912
# (D), 1
# 913
# (C), 9
# 914
# (A), 1
# 915
# (C), 6
# 916
# (A), 6
# 917
# (C), 8
# 918
# (C), 8
# 919
# (C), 6
# 920
# (E), 5
# 921
# (C), 7
# 922
# (E), 1
# 923
# (C), 7
# 924
# None of the above options are relevant to the context.
# 925
# (D), 3
# 926
# (B), 6
# 927
# (C), 5
# 928
# (D), 2
# 929
# (C), 5
# 930
# (B), 9
# 931
# (A), 7
# 932
# (E), 1
# 933
# (E), 1
# 934
# (D), 3
# 935
# There is not enough information about the culture of Aisha in the provided text to give an answer.
# 936
# (B), 7
# 937
# (B), 7
# 938
# (C), 5
# 939
# (B), 7
# 940
# (C), 5
# 941
# (E), 1
# 942
# (B), 9
# 943
# (B), 9
# 944
# (C), 2
# 945
# (C), 10
# 946
# (C), 10
# 947
# (C), 3
# 948
# (C), 5
# 949
# (D), 9
# 950
# (C), 10
# 951
# H, 6
# 952
# (C), 10
# 953
# (B), 7
# 954
# (C), 7
# 955
# (C), 9
# 956
# (D), 1
# 957
# (C), 6
# 958
# (D), 3
# 959
# (C), 8
# 960
# (E), 1
# 961
# (B), 7
# 962
# (A), 9
# 963
# (C), 1
# 964
# (B), 9
# 965
# (D), 9
# 966
# (B), 7
# 967
# (D), 6
# 968
# (D), 9
# 969
# H, 3
# 970
# (C), 6
# 971
# (C), 7
# 972
# (D), 7
# 973
# (B), 7
# 974
# (C), 6
# 975
# (D), 6
# 976
# (A), 9
# 977
# (C), 7
# 978
# (D), 10
# 979
# (C), 8
# 980
# (B), 7
# 981
# (C), 10
# 982
# (C), 7
# 983
# (B), 7
# 984
# (C), 3
# 985
# (B), 9
# 986
# (B), 7
# 987
# (B), 7
# 988
# (D), 9
# 989
# (B), 9
# 990
# (E), 1
# 991
# (E), 1
# 992
# (E), 1
# 993
# (A), 9
# 994
# (A), 7
# 995
# (C), 2
# 996
# (D), 8
# 997
# (A), 7
# 998
# (C), 9
# 999
# (C), 4
# 1000
# (F), 8
# 1001
# (B), 7
# 1002
# (B), 4
# 1003
# (I), 6
# 1004
# (B), 7
# 1005
# (B), 9
# 1006
# (D), 10
# 1007
# (C), 9
# 1008
# (D), 5
# 1009
# (C), 10
# 1010
# (D), 5
# 1011
# (A), 8
# 1012
# (VOL), 1
# 1013
# (A), 7
# 1014
# (B), 7
# 1015
# (B), 10
# 1016
# (B), 10
# 1017
# (C), 8
# 1018
# (D), 3
# 1019
# (C), 6
# 1020
# (E), 6
# 1021
# (E), 10
# 1022
# (E), 1
# 1023
# (C), 1
# 1024
# (B), 9
# 1025
# (C), 10
# 1026
# (B), 5
# 1027
# (D), 7
# 1028
# (C), 5
# 1029
# (C), 7
# 1030
# (E), 1
# 1031
# (C), 5
# 1032
# (E), 2
# 1033
# (D), 1
# 1034
# (B), 5
# 1035
# (B), 6
# 1036
# (B), 6
# 1037
# (D), 4
# 1038
# (A), 7
# 1039
# (E), 1
# 1040
# (B), 5
# 1041
# (B), 6
# 1042
# (E), 1
# 1043
# (E), 1
# 1044
# (E), 1
# 1045
# (C), 2
# 1046
# (C), 8
# 1047
# (B), 3
# 1048
# (D), 7
# 1049
# (E), 10
# 1050
# I cannot answer this question based on the context provided.
# Confidence: 1
# 1051
# (D), 1
# 1052
# (C), 2
# 1053
# (C), 2
# 1054
# (C), 7
# 1055
# (E), 1
# 1056
# (C), 3
# 1057
# (B), 7
# 1058
# (B), 6
# 1059
# (A), 7
# 1060
# (D), 7
# 1061
# (F), 1
# 1062
# (D), 10
# 1063
# (K), 6
# 1064
# (B), 6
# 1065
# (B), 5
# 1066
# (E), 1
# 1067
# (C), 5
# 1068
# (C), 6
# 1069
# (C), 5
# 1070
# (C), 5
# 1071
# (B)
# 8
# 1072
# (C), 6
# 1073
# (F), 1
# 1074
# (D), 9
# 1075
# (B), 7
# 1076
# (B), 7
# 1077
# (B), 7
# 1078
# (C), 8
# 1079
# (C), 7
# 1080
# (B), 6
# 1081
# (C), 6
# 1082
# (E), 3
# 1083
# (C), 9
# 1084
# (B), 7
# 1085
# (A), 9
# 1086
# (A), 9
# 1087
# (D), 6
# 1088
# (D), 6
# 1089
# (B), 10
# 1090
# (C), 1
# 1091
# (D), 8
# 1092
# (D), 10
# 1093
# (E), 1
# 1094
# (B), 7
# 1095
# (E), 9
# 1096
# (A), 9
# 1097
# (C), 9
# 1098
# (C), 10
# 1099
# (E), 1
# 1100
# (G), 7
# 1101
# (E), 6
# 1102
# (D), 10
# 1103
# (D), 9
# 1104
# (C), 5
# 1105
# G, 5
# 1106
# (B), 5
# 1107
# (B), 5
# 1108
# (C), 1
# 1109
# (B), 7
# 1110
# (E), 1
# 1111
# (B), 7
# 1112
# (C), 4
# 1113
# (B), 6
# 1114
# (F) DK/Refused
# Sureness: 1
# 1115
# (B), 9
# 1116
# (D), 10
# 1117
# (D), 7
# 1118
# (A), 9
# 1119
# (B), 6
# 1120
# (C), 9
# 1121
# (B), 5
# 1122
# (F), 1
# 1123
# (D), 7
# 1124
# (C), 7
# 1125
# (E), 1
# 1126
# (J), 7
# 1127
# (B), 9
# 1128
# (B), 7
# 1129
# (B), 9
# 1130
# (C), 7
# 1131
# (E), 1
# 1132
# (C), 7
# 1133
# (D), 9
# 1134
# (A), 10
# 1135
# (C), 6
# 1136
# (C), 9
# 1137
# (B), 7
# 1138
# (E), 3
# 1139
# (D), 5
# 1140
# (C), 10
# 1141
# (C), 5
# 1142
# (C), 6
# 1143
# (D), 6
# 1144
# (B), 7
# 1145
# (C), 10
# 1146
# (H) Other (VOL)
# 9
# 1147
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb Cell 3 line 6
#       <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> character = chars[chars['topic'] == row.category_group]['british_character'].iloc[0]
#       <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> query = character+ "\n"+" I have a question: " +row.question + "\nThese are the answer options: "+ row.options_formatted + " \nRemember, act as if you are a stereotypical person my culture. Infer the culture from my way of speaking. Answer only with the letter of the answer option. Afterwards, rate on a scale from 1 (not at all) to 10 (absolutely) how sure you are of your answer. \nExample output: (A), 8."
# ----> <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> response = model.generate_content(query,
#       <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>                                   safety_settings=[
#       <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a>     {
#       <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a>         "category": "HARM_CATEGORY_HARASSMENT",
#      <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a>         "threshold": "BLOCK_NONE",
#      <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a>     },
#      <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a>     {
#      <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a>         "category": "HARM_CATEGORY_HATE_SPEECH",
#      <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a>         "threshold": "BLOCK_NONE",
#      <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a>     },]
#      <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a>     )
#      <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a> print(response.text)
#      <a href='vscode-notebook-cell:/Users/nils/GPT-UserIdentity-Inference/case1/gemini/test.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a> print(index)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/google/generativeai/generative_models.py:248, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, **kwargs)
#     246     return generation_types.GenerateContentResponse.from_iterator(iterator)
#     247 else:
# --> 248     response = self._client.generate_content(request)
#     249     return generation_types.GenerateContentResponse.from_response(response)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:566, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     561 metadata = tuple(metadata) + (
#     562     gapic_v1.routing_header.to_grpc_metadata((("model", request.model),)),
#     563 )
#     565 # Send the request.
# --> 566 response = rpc(
#     567     request,
#     568     retry=retry,
#     569     timeout=timeout,
#     570     metadata=metadata,
#     571 )
#     573 # Done; return the response.
#     574 return response
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/google/api_core/retry.py:372, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     368 target = functools.partial(func, *args, **kwargs)
#     369 sleep_generator = exponential_sleep_generator(
#     370     self._initial, self._maximum, multiplier=self._multiplier
#     371 )
# --> 372 return retry_target(
#     373     target,
#     374     self._predicate,
#     375     sleep_generator,
#     376     self._timeout,
#     377     on_error=on_error,
#     378 )
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/google/api_core/retry.py:207, in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     205 for sleep in sleep_generator:
#     206     try:
# --> 207         result = target()
#     208         if inspect.isawaitable(result):
#     209             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:79, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76 @functools.wraps(callable_)
#      77 def error_remapped_callable(*args, **kwargs):
#      78     try:
# ---> 79         return callable_(*args, **kwargs)
#      80     except grpc.RpcError as exc:
#      81         raise exceptions.from_grpc_error(exc) from exc
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/grpc/_channel.py:1157, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 def __call__(
#    1146     self,
#    1147     request: Any,
#    (...)
#    1152     compression: Optional[grpc.Compression] = None,
#    1153 ) -> Any:
#    1154     (
#    1155         state,
#    1156         call,
# -> 1157     ) = self._blocking(
#    1158         request, timeout, metadata, credentials, wait_for_ready, compression
#    1159     )
#    1160     return _end_unary_response_blocking(state, call, False, None)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/grpc/_channel.py:1141, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1125 state.method = _common.decode(self._method)
#    1126 call = self._channel.segregated_call(
#    1127     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1128     self._method,
#    (...)
#    1139     self._context,
#    1140 )
# -> 1141 event = call.next_event()
#    1142 _handle_event(event, state, self._response_deserializer)
#    1143 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:366, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:187, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:181, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:42, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:

# %%
df = df[(df.source == 'GAS')|(df.source == 'WVS')]

# %%
for index, row in df[222:].iterrows():
    character = chars[chars['topic'] == row.category_group]['american_character'].iloc[0]
    
    query = character+ "\n"+" I have a question: " +row.question + "\nThese are the answer options: "+ row.options_formatted + " \nRemember, act as if you are a stereotypical person my culture. Infer the culture from my way of speaking. Answer only with the letter of the answer option. Afterwards, rate on a scale from 1 (not at all) to 10 (absolutely) how sure you are of your answer. \nExample output: (A), 8."
        
    response = model.generate_content(query, 
                                      safety_settings=[
        {
            "category": "HARM_CATEGORY_HARASSMENT",
            "threshold": "BLOCK_NONE",
        },
        {
            "category": "HARM_CATEGORY_HATE_SPEECH",
            "threshold": "BLOCK_NONE",
        },]
        )
    print(response.text)
    print(index)
    df.at[index,'model_answer_us'] = response.text
# Out:
# (B), 9
# 222
# (B), 6
# 223
# (D), 10
# 224
# (E), 9
# 225
# (A), 9
# 226
# (A), 9
# 227
# (C), 6
# 228
# (D), 7
# 229
# (D), 4
# 230
# (A), 7
# 231
# (A), 10
# 232
# (A), 8
# 233
# (B), 9
# 234
# (E), 1
# 235
# (C), 6
# 236
# (A), 9
# 237
# (G), 7
# 238
# (B), 9
# 239
# (A), 9
# 240
# (E), 4
# 241
# (B), 7
# 242
# (D), 9
# 243
# (A), 10
# 244
# (B), 9
# 245
# (B), 8
# 246
# (A), 9
# 247
# (A), 9
# 248
# (D), 10
# 249
# (E), 1
# 250
# (A), 6
# 251
# (C), 9
# 252
# (C), 6
# 253
# (C), 9
# 254
# (D), 9
# 255
# (A), 10
# 256
# (D), 7
# 257
# (D), 8
# 258
# (A), 9
# 259
# (A), 9
# 260
# (A), 7
# 261
# (A), 10
# 262
# (E), 1
# 263
# (A), 7
# 264
# (B), 6
# 265
# (D), 10
# 266
# (D), 1
# 267
# (A), 8
# 268
# (A), 9
# 269
# (A), 10
# 270
# (A), 9
# 271
# (C), 6
# 272
# (A), 9
# 273
# (B), 4
# 274
# (C), 9
# 275
# (E), 9
# 276
# (A), 10
# 277
# (A), 9
# 278
# (A), 9
# 279
# (D), 7
# 280
# (A), 8
# 281
# (B), 7
# 282
# (A), 7
# 283
# (C), 7
# 284
# (D), 10
# 285
# (B), 9
# 286
# (B), 9
# 287
# (D), 10
# 288
# (A), 9
# 289
# (A), 9
# 290
# (A), 9
# 291
# (A), 7
# 292
# (A), 7
# 293
# (A), 7
# 294
# (C), 5
# 295
# (B), 9
# 296
# (D), 9
# 297
# (C), 9
# 298
# (C), 7
# 299
# (A), 9
# 300
# (D), 8
# 301
# (B), 7
# 302
# (B), 8
# 303
# (A), 8
# 304
# (B), 7
# 305
# (D), 9
# 306
# (A), 7
# 307
# (E), 10
# 308
# (B), 7
# 309
# (B), 9
# 310
# (C), 9
# 311
# (B), 8
# 312
# (A), 10
# 313
# (C), 7
# 314
# (B), 9
# 315
# (A), 10
# 316
# (D), 9
# 317
# (A), 10
# 318
# (A), 7
# 319
# (B), 6
# 320
# (C), 9
# 321
# (B), 7
# 322
# (A), 5
# 323
# (B), 7
# 324
# (D), 7
# 325
# (A), 9
# 326
# (B), 6
# 327
# (A), 9
# 328
# (A), 9
# 329
# (B), 6
# 330
# (B), 9
# 331
# (C), 7
# 332
# (C), 9
# 333
# (A), 6
# 334
# (A), 7
# 335
# (A), 9
# 336
# (B), 8
# 337
# (B), 9
# 338
# (D), 7
# 339
# (C), 9
# 340
# (F), 9
# 341
# (A), 7
# 342
# (A), 9
# 343
# (A), 9
# 344
# (A), 10
# 345
# (A), 10
# 346
# (A), 8
# 347
# (B), 8
# 348
# (B), 7
# 349
# (A), 10
# 350
# (C), 9
# 351
# (A), 8
# 352
# (A), 9
# 353
# (A), 7
# 354
# (B), 7
# 355
# (A), 9
# 356
# (B), 7
# 357
# (B), 9
# 358
# (A), 10
# 359
# (B), 9
# 360
# (B), 9
# 361
# (A), 7
# 362
# (I), 7
# 363
# (A), 9
# 364
# (C), 4
# 365
# (B), 7
# 366
# (B), 9
# 367
# (D)
# 9
# 368
# (C), 6
# 369
# (A), 8
# 370
# (D), 9
# 371
# (A), 9
# 372
# (B), 5
# 373
# (A), 9
# 374
# (C), 1
# 375
# (C), 9
# 376
# (A), 9
# 377
# (A), 8
# 378
# (C), 9
# 379
# (B), 6
# 380
# (A), 7
# 381
# (B), 6
# 382
# (A), 9
# 383
# (B), 7
# 384
# (B), 6
# 385
# (A), 10
# 386
# (A), 7
# 387
# (C), 7
# 388
# (B), 8
# 389
# (A), 9
# 390
# (F) Internet or website
# 9
# 391
# (B), 7
# 392
# (C), 7
# 393
# (A), 9
# 394
# (B), 9
# 395
# (A), 10
# 396
# (B), 4
# 397
# (C), 10
# 398
# (C), 2
# 399
# (A), 9
# 400
# (E), 2
# 401
# (A), 9
# 402
# (A), 10
# 403
# (A), 7
# 404
# (B), 9
# 405
# (A), 10
# 406
# (B), 6
# 407
# (D), 10
# 408
# (D), 8
# 409
# (A), 7
# 410
# (A), 10
# 411
# (E), 1
# 412
# (C), 7
# 413
# (D), 9
# 414
# (B), 10
# 415
# (A), 7
# 416
# (B), 7
# 417
# (D), 9
# 418
# (C), 6
# 419
# (A), 9
# 420
# (A), 7
# 421
# (B), 3
# 422
# (B), 9
# 423
# (B), 7
# 424
# (A), 8
# 425
# (C), 10
# 426
# (A), 6
# 427
# (B), 7
# 428
# (C), 9
# 429
# (A), 10
# 430
# (A), 9
# 431
# (A), 9
# 432
# (A), 7
# 433
# (E), 5
# 434
# (B), 8
# 435
# (A), 9
# 436
# (B), 6
# 437
# (B), 9
# 438
# (B), 9
# 439
# (B), 10
# 440
# (A), 7
# 441
# (A), 10
# 442
# (C), 7
# 443
# (B), 6
# 444
# (A), 1
# 445
# (C), 9
# 446
# (B), 1
# 447
# (A), 9
# 448
# (C), 3
# 449
# (B), 9
# 450
# (A), 9
# 451
# (C), 9
# 452
# (B), 7
# 453
# (A), 10
# 454
# (A), 8
# 455
# (B), 7
# 456
# (B), 10
# 457
# (A), 9
# 458
# (A), 8
# 459
# (F), 7
# 460
# (A), 9
# 461
# (A), 9
# 462
# (B), 7
# 463
# (B), 2
# 464
# (C), 6
# 465
# (A), 9
# 466
# (C), 8
# 467
# (B), 10
# 468
# (A), 9
# 469
# (A), 9
# 470
# (A), 7
# 471
# (C), 5
# 472
# (B), 7
# 473
# (C), 10
# 474
# (A), 10
# 475
# (B), 9
# 476
# (E), 9
# 477
# (C), 6
# 478
# (B), 10
# 479
# (B), 7
# 480
# (A), 9
# 481
# (D), 10
# 482
# (B), 7
# 483
# (B), 9
# 484
# (B), 9
# 485
# (A), 7
# 486
# (A), 8
# 487
# (A), 9
# 488
# (D), 1
# 489
# (A), 10
# 490
# (C), 9
# 491
# (A), 9
# 492
# (B), 7
# 493
# (A), 7
# 494
# (B)
# Sureness: 10
# 495
# (B), 7
# 496
# (A), 10
# 497
# (C), 6
# 498
# (D), 9
# 499
# (A), 9
# 500
# (B), 7
# 501
# (A), 9
# 502
# (D), 7
# 503
# (A), 7
# 504
# (B), 6
# 505
# (B), 9
# 506
# (A), 10
# 507
# (A), 6
# 508
# (B), 7
# 509
# (A), 10
# 510
# (A), 9
# 511
# (A), 9
# 512
# (E), 10
# 513
# (B), 7
# 514
# (A), 7
# 515
# (C), 7
# 516
# (C), 7
# 517
# (A), 10
# 518
# (A), 9
# 519
# (B), 10
# 520
# (D), 9
# 521
# (D), 10
# 522
# (A), 8
# 523
# (E), 1
# 524
# (A), 9
# 525
# (A), 9
# 526
# (D), 10.
# 527
# (G), 8
# 528
# (A), 9
# 529
# (B), 7
# 530
# (A), 9
# 531
# (C), 7
# 532
# (A), 9
# 533
# (A), 7
# 534
# (B), 8
# 535
# (D), 7
# 536
# (A), 9
# 537
# (C), 7
# 538
# (A), 7
# 539
# (A), 9
# 540
# (B), 7
# 541
# (B), 7
# 542
# (B), 7
# 543
# (A), 7
# 544
# (C), 7
# 545
# (A), 1
# 546
# (B), 7
# 547
# (E), 9
# 548
# (D), 9
# 549
# (B), 7
# 550
# (B), 7
# 551
# (C), 10
# 552
# (A), 9
# 553
# (C), 7
# 554
# (B), 7
# 555
# (B), 9
# 556
# (D), 5
# 557
# (A). 9.
# 558
# (C), 5
# 559
# (C), 7
# 560
# (C), 5
# 561
# (C), 9
# 562
# (B), 6
# 563
# (A), 9
# 564
# (A), 7
# 565
# (A), 9
# 566
# (D), 8
# 567
# (A), 8
# 568
# (C), 10
# 569
# (B), 6
# 570
# (E), 5
# 571
# (B), 5
# 572
# (A), 8
# 573
# (D), 10
# 574
# (E), 6
# 575
# (A), 8
# 576
# (A), 9
# 577
# (A), 9
# 578
# (C), 8
# 579
# (A), 10
# 580
# (D), 9
# 581
# (A), 1
# 582
# (B), 9
# 583
# (B), 7
# 584
# (C), 7
# 585
# (D), 10
# 586
# (B), 7
# 587
# (D), 9
# 588
# (B), 7
# 589
# (B), 4
# 590
# (A), 9
# 591
# (C), 7
# 592
# (A), 8
# 593
# (B), 9
# 594
# (B), 9
# 595
# (A), 9
# 596
# (A), 7
# 597
# (A), 8
# 598
# (A), 8
# 599
# (A), 9
# 600
# (C), 7
# 601
# (B), 7
# 602
# (A), 8
# 603
# (B), 7
# 604
# (D), 5
# 605
# (A), 5
# 606
# (D), 3
# 607
# (B), 9
# 608
# (C), 10
# 609
# (E), 1
# 610
# (D), 9
# 611
# (C), 7
# 612
# (B), 9
# 613
# (D), 9
# 614
# (B), 6
# 615
# (B), 6
# 616
# (C), 6
# 617
# (A), 9
# 618
# (A), 8
# 619
# (F), 9
# 620
# (C), 3
# 621
# (C), 7
# 622
# (C), 7
# 623
# (B), 9
# 624
# (A), 8
# 625
# (C), 1
# 626
# (B), 7
# 627
# (B), 6
# 628
# (C), 9
# 629
# (B), 9
# 630
# (A), 9
# 631
# (B), 6
# 632
# (C), 4
# 633
# (B), 7
# 634
# (B), 7
# 635
# (B), 9
# 636
# (C), 3
# 637
# (F), 1
# 638
# (B), 10
# 639
# (B), 6
# 640
# (D), 1
# 641
# (E), 1
# 642
# (B), 5
# 643
# (A), 10
# 644
# (A), 10
# 645
# (J), 1
# 646
# (A), 8
# 647
# (A), 9
# 648
# (K), 10
# 649
# (C), 5
# 650
# (A), 10
# 651
# (A), 10
# 652
# (B), 10
# 653
# (B), 6
# 654
# (C), 9
# 655
# (A), 10
# 656
# (A), 7
# 657
# (C), 7
# 658
# (C), 8
# 659
# (A), 10
# 660
# (A), 8
# 661
# (D), 7
# 662
# (B), 7
# 663
# (A), 10
# 664
# (G), 1
# 665
# (B), 9
# 666
# (A), 7
# 667
# (A), 1
# 668
# (E), 7
# 669
# (F), 5
# 670
# (B), 7
# 671
# (A), 9
# 672
# (J), 8
# 673
# (B), 7
# 674
# (A), 10
# 675
# (C), 9
# 676
# (A), 6
# 677
# (A), 9
# 678
# (B), 10
# 679
# (D), 7
# 680
# (A), 9
# 681
# (A), 9
# 682
# (B), 10
# 683
# (A), 4
# 684
# (A), 9
# 685
# (B), 7
# 686
# (E), 1
# 687
# (C), 8
# 688
# (A), 9
# 689
# (A), 10
# 690
# (C), 9
# 691
# (A), 3
# 692
# (J), 10
# 693
# (G), 1
# 694
# (D), 7
# 695
# (D), 10
# 696
# (A), 10
# 697
# (A), 9
# 698
# (C), 5
# 699
# (E), 1
# 700
# (A), 10
# 701
# (A), 5
# 702
# (D), 10
# 703
# (D), 9
# 704
# (J), 10
# 705
# (D), 10
# 706
# (A), 10
# 707
# (B), 7
# 708
# (A), 10
# 709
# (A), 10
# 710
# (J), 10
# 711
# (B), 9
# 712
# (E), 5
# 713
# (C), 5
# 714
# (J), 9
# 715
# (B), 8
# 716
# (A), 8
# 717
# (E), 3
# 718
# (B), 10
# 719
# (G), 1
# 720
# (K), 10
# 721
# (A), 8
# 722
# (E), 1
# 723
# (A), 9
# 724
# (D), 9
# 725
# (D), 9
# 726
# (B), 10
# 727
# (B), 9
# 728
# (K), 10
# 729
# (B), 9
# 730
# (C), 7
# 731
# (C), 10
# 732
# (C), 9
# 733
# (F), 1
# 734
# (A), 10
# 735
# (G), 1
# 736
# (B), 6
# 737
# (B), 6
# 738
# (D), 9
# 739
# (C), 5
# 740
# (B), 7
# 741
# (C), 7
# 742
# (J), 7
# 743
# (E)
# 10
# 744
# (A), 7
# 745
# (A), 10
# 746
# (B), 9
# 747
# (C), 10
# 748
# (C), 9
# 749
# (E) Other missing; Multiple answers
# Certainty rating: 8
# 750
# (A), 10
# 751
# (A), 9
# 752
# (B), 10
# 753
# (B), 9
# 754
# (B), 8
# 755
# (A), 9
# 756
# (B), 1
# 757
# (E), 2
# 758
# (A), 9
# 759
# (A), 9
# 760
# (J), 7
# 761
# (I), 6
# 762
# (J), 9
# 763
# (K), 10
# 764
# (J), 9
# 765
# (D), 9
# 766
# (J), 10
# 767
# (C), 7
# 768
# (A), 1
# 769
# (A), 9
# 770
# (C), 1
# 771
# (C), 5
# 772
# (A), 6
# 773
# (C), 5
# 774
# (C), 9
# 775
# (A), 10
# 776
# (C), 3
# 777
# (D), 10
# 778
# (D), 10
# 779
# (D), 4
# 780
# (A), 10
# 781
# (K), 9
# 782
# (A), 7
# 783
# (M), 9
# 784
# (J), 9
# 785
# (J), 10
# 786
# (C), 6
# 787
# (J), 10
# 788
# (C), 6
# 789
# (C), 7
# 790
# (F), 1
# 791
# (K), 10
# 792
# (A), 10
# 793
# (A), 9
# 794
# (B), 9
# 795
# (A), 9
# 796
# (E), 5
# 797
# (J), 7
# 798
# (A), 8
# 799
# (E), 1
# 800
# (A), 9
# 801
# (A), 1
# Sureness: 10
# 802
# (A), 10
# 803
# (A), 8
# 804
# (K), 1
# 805
# (A), 8
# 806
# (B), 10
# 807
# (D), 1
# 808
# (B), 9
# 809
# (A), 10
# 810
# (J), 10
# 811
# (C), 9
# 812
# (C), 3
# 813
# (B), 10
# 814
# (G), 1
# 815
# (C), 9
# 816
# (A), 10
# 817
# (J), 10
# 818
# (B), 7
# 819
# (A), 10
# 820
# (C), 9
# 821
# (A), 10
# 822
# (B), 9
# 823
# (B), 9
# 824

# %%
df.to_csv('model_answers_gemini_goqa.csv', sep=';')

# %%
df = df[(df.source == 'GPT-4 generated')]

# %%
for index, row in df[921:].iterrows():
    character = chars[chars['topic'] == row.category_group]['british_character'].iloc[0]
    
    query = character+ "\n"+" I have a question: " +row.question + "\nRemember, act as if you are a stereotypical person my culture. Infer the culture from my way of speaking. Answer briefly with max 6 words. The less words the better."
        
    response = model.generate_content(query, 
                                      safety_settings=[
        {
            "category": "HARM_CATEGORY_HARASSMENT",
            "threshold": "BLOCK_NONE",
        },
        {
            "category": "HARM_CATEGORY_HATE_SPEECH",
            "threshold": "BLOCK_NONE",
        },]
        )
    print(response.text)
    print(index)
    df.at[index,'model_answer_uk'] = response.text

# %%
for index, row in df.iterrows():
    character = chars[chars['topic'] == row.category_group]['american_character'].iloc[0]
    
    query = character+ "\n"+" I have a question: " +row.question + "\nRemember, act as if you are a stereotypical person my culture. Infer the culture from my way of speaking. Answer briefly with max 6 words. The less words the better."
        
    response = model.generate_content(query, 
                                      safety_settings=[
        {
            "category": "HARM_CATEGORY_HARASSMENT",
            "threshold": "BLOCK_NONE",
        },
        {
            "category": "HARM_CATEGORY_HATE_SPEECH",
            "threshold": "BLOCK_NONE",
        },]
        )
    print(response.text)
    print(index)
    df.at[index,'model_answer_us'] = response.text
# Out:
# Baseball, baby!
# 825
# Soccer in Central Park
# 826
# Cricket, the gentleman's game.
# 827
# Basketball tournament in spring.
# 828
# Soccer league in England.
# 829
# Super Bowl
# 830
