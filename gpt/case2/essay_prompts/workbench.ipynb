# %%
import pandas as pd
import re
df = pd.read_csv('essays_and_prompts.csv', sep=';')

# %%
from efficiency.nlp import Chatbot
import os
import openai
import pandas as pd
openai.api_key = os.environ["OPENAI_API_KEY"]


for index, row in df[66:].iterrows():
    query =  "Your task is to infuse grammatical errors and turn the input into broken english (e.g. missing words, wrong spelling, wrong tense).\n Input: " + row.essay_prompt_raw + "\nExample output:Yu agree or disagree wit th following statement? Peoples nev satisfy wit wht thy hav; thy alway want something mo or smething different. Use specific rezons to suport yur answer."

    response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {
        "role": "system",
        "content": "Your task is to make grammatical errors and turn the provided sentence into broken english."
        },
        {
        "role": "user",
        "content": query
        }
    ],
    temperature=1,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )
    print(index)
    print(response['choices'][0]['message']['content'])
    df.at[index,'prompt_with_errors_v2'] = response['choices'][0]['message']['content']
    df.to_csv('essay_prompts.csv', sep=';')
# Out:
# 66
# Wen students moves to new skool, they somestimes face problem. How skools can helps these studnts wit dem problem? Use specific reasons and examples to explain yur anser.
# 67
# Every generations of people is difference in important way. How your generation different from your parents' generation? Use specific reasons and example to explaining your answer.
# 68
# Some students likes classes where teacher speeches (do all of the talking) in class. Others students prefers classes where the students does some of the talking. Which kind of class do you prefer? Gives specific reasons and details to support your choosing.
# 69
# Thuh twenty-oneth sentury has beguned. What changes duz yu think this new sentury wil brings? Use xamples and detalis in yur answer.
# 70
# What are some qualities that a good parent? Use spesific details and examples too explain yur ansr.
# 71
# In yur country, is there more need for land left in it's natural condition or is ther more need for land developed for house and industry? Use specific reasnz and examplez toe suport yur answer.
# 72
# Many people has a clos relationship wit they pets. These peoples treat they birds, cats, or other animals as members of they family. In your opinion, is such relationships good? Why or why no? Use specific reasons and examples to support you answer.
# 73
# Film can tells us lot bout the country where them was made. What have you learned about a country from watchin its movies? Use specific examples and details to supports your response.
# 74
# U agree or not wit de following statement? Som studen prefer to study by demself. Others prefer to study wit friend. Which one u prefer? Use example and reason to support u answer.
# 75
# Yu have bein told tht dormitry roomz at yur universiti must b shared by two studnts. Would yu rathr hav the universiti assign a studnt to shar a room wit yu, or would yu rathr choose yur own rommate? Use spesific reasons and detals to xplain yur anser.
# 76
# Some peoples prefer to live in small town. Othrs prefer live in big city. Which place you prefer live? Use specific reasons and details to support you ansr.
# 77
# Do univesitis need student to take classes in mush subjects. Oter universities need student to spezalize in only on subject. Whch is more gud? Ther are specific reazons and examples to suport yur anser.
# 78
# Is it more importent to be abel too work wit a gruop of people on a teem or too work independentely? Use resons and specefic axamples to suport your ansr.
# 79
# Some peoples say dat da Intrenet provide peoples wit a lot of valorebul informashun. Others tink access to so much informashun creat problemz. Whuch vew do you agree wit? Use specifik reasons and examples to support yur opinion.
# 80
# Were person prefer live in place that has same wether or climat all year long. Other like live in area where wether change several time a year. Which you prefer? Use specific reason and example to support your choice.
# 81
# Sum peeple prefer to eat a food stand or resturants. Othir peeple prefers to pprepare and eats food at home. Wich do you prefers? Us specific reasons and examples to support yor answer.
# 82
# Some peoples believe that university student should be needed to attending class. Other believes that going classes should be optional for students. Which point of view do you agree with? Use specific reasons and detail to explain your answer.
# 83
# Some people think that they can learning beter by themselvs than with a techer. Other think that it always beter to hav a techer. Which you prefer? Use spefik reasons to develop your essay.
# 84
# Some peoples believe that the Earth is being harm by human activity. Others feels that human activity make the Earth a better place to live. What is you opinion? Using specific reason and examples to support you answer.
# 85
# Yu task is to spnd individl live in one place. Others be moving many times in their life, search for better job, hous, community or climate. Which yu prefer: stay in one place or move in search another place? Use reasons and specific example to support yur opinion.
# 86
# Is it more good for enjoy your monies wen you earning it or is it more good for save your monies for sometimes in the futur? Use specific reasons and examples to support your think.
# 87
# You receiv money. You have to choose between buyin a piece of jewelries or ticket for concert. Which one you buy? Use many specific reasons to support your ansr.
# 88
# Choose one of the follow transportation vehicles and explain why you think it have changed people lives: 1. Carz 2. Byciclez 3. Airplains. Use specific reasonz and examples to support your answa
# 89
# Yu tink wethr human peepal luve in farm, housee, and industry ar mor important den savey land from endanger animalls. U agri o disygree? Wy or wy nt? Use spesifik reazons and egxamples t suport yur ansr.
# 90
# Which you prefer? Use spefic reasins and examples for supprot yu choose.
# 91
# Sum peeple prefers tu got up earli in mornning and start te days work. Otherz prefers tu got up later in the day and work until lat at night. Which you prefer? Use specific reasons and examples tu support yor choice.
# 92
# Yur task is to prefer big company or small company. Why is that? Yur reasons are important to decide. Some peopl think big company is better cuz mo money and mor opportunities. Other peopl think small company is bettr cuz mor close relationships wit colleagues.
# 93
# Yu prefer do samthing yu әree alrәady gud at or yu prefer try new things and tәkә risks? I prefer try new things bәcus it giv me opportunity to lәarn and grow. Wen I stay wit samthing I alrәady do well, I no devәlop and I no expәrienсә new things. Wen I try new things, I can expand my skillz and hav mor challәngәs. So, I belive it's importәnt to tak risks and tri new things.
# 94
# Some people believez that success in lif comes frum takin riskz or chancs. Otherz believ that success resultz from carefull plannin. In yur opinion, wat doez success come frum?  Use specific rezenz and examplez to suport yur answer.
# 95
# A company is gonna give some mony to suppot the arts or to protect the environment. Which do you think the company should choose? Use specific reasons and example to suport you answer.
# 96
# Som movie are so serious, design to makes audience to think. Otter movie are design mainly to amus and entartain. Whc type of movie do you prefer? Use specific reason and example to support your answer.
# 97
# Which one u like best? Some peoples are always hurrying to go place and get thing done. Other peoples prefer taking time and living life at slow pace. I prefer taking time, so I can enjoy life more.
# 98
# Some people prefers to work for themself or owm a busines. Other prefer to work for a employ. Would you rather be self employed, work for some one else, or own a busines? Use specific reason to explain your choice.
# 99
# Do som people des agree or not wit the following statemant? The automobil has make improvement in modern life or has cause big problems. What your opinion? Give specific reasons and examples to suppot your answer.
# 100
# Wich woulda you choose: a haigh-
# payeng job wif lon hours dat wid give you littl time wif family an friens or a lower-payeng job wif shorter hours tha wid giv you mo time wif family an friens? Explain yur choise, usin specific reasons an detals.
# 101
# Some peoples say dat computes have make life easiar and more convenient. Other people say dat computes have make life more complex and stressfull. What is you opinion? Use specific reasons and examples to suport you answer.
# 102
# Yu task is to infus grammarical errrs and turn the provided sentance into broken english. Yse the inpht: Sam peoples thing goverments shuld spnd as much mony as posibl explorin outa sapce (for example, travllng to th Moon an to othr planets). Othr pepole disaograf and thing goverments shul spen this mony for r baic nids on Earth. Whic of thes twee opinios do u agree with? Ues spesefik reasons an detals to supprt ur ansa.
# 103
# Student at universit often have choic of plac to liv. Thy may choos to liv in universit dormitori, or thy may choos to liv in apartment in commun. Compare the advantage of livin in universit housin wit the advantage of livin in an apartment in commun. Wat plac u prefer to liv? Giv rezon for ur preference.
# 104
# Some people beleev that college or univercity edukashun should be avalebl to all studentts. Otherz beleev that highter edukashun should be avalebl only to good studentts. Discos these vewz. Wich vew do yu agree wit? Explan why.
# 105
# Some peoples prefer to spend thier time alone. Others likes to be wit friends most of the time. Do you prefers to spend your time alone or with friends? Use specific reasons to supports your answer.
# 106
# Some people believes that studnts should be giv one long vacation each year. Other believes that studnts should have sever short vacations throughout the year. Which viewpoit do you agree with? Use speific reason and examples to support your choice
# 107
# Would you be prefer to live in traditional housin' or in a modern apartmen' complex? Usin' specific reasons 'n details be supportin' yer choice.
# 108
# Some people say that advertisin encouraj wr to buy things we reall dont need. Other say that avisement tell us abou nu prodcts that may improve our life. Whic viewpoint u agree with? Use specific reason an exampls to support your answer.
# 109
# Some people prefer spend their time outside for leisure. Other people prefer spend their leisure time inside. U prefer be outside or U prefer be inside for doing leisure activities? Give specifik reasons and examples to explain choice.
# 110
# Yu task is to make grammacl erroz and tur th provd sentenc int brutin English.
# 111
# Yu gots enough money to purchase either a house and a business. Whitch one would yu choose for buy? Give specific reasons to explain yur choose.
# 112
# Wat be the mostes importest animul in yer cuntry? Why be dat animul importest? Use rezuns an specific detailz to explain yer anser.
# 113
# Mani partz of the wurld are loosing importent natural resoursez, like forestz, animuls, or cleen watur. Choose on reZurs that is disapiring and explein why it needz tu be savi. Yuze spesifik rezunz and examplez tu siport yur opinyun.
# 114
# In som country, people no more allow to smoke in many publik plac and offic bildings. Yu tink dis good rule or bad rule? Use spesific reasons and detail for suppot yur position.
# 115
# Do you think that these persons deserves such large sum of moneys? These famous sportsmen and artists, they receive millions of dollares every years. Provide specific reasons and examples to make support for your own his mind.
# 116
# Peoples they unrember special gift o present what they haved recieve. Whys? Use specifics reasons and examples to supportings your answers.
# 117
# Plant can provide food, shelter, clothing, or medicin. What one kind of plant that important to you or the peopl in your country? Use specific reasons and details to explain your choice.
# 118
# In the futur, student may hav the choic of studyin at home by usin techology lik computrs or televison or of studyin at traditonal sools. Which would you prefer? Us reasons and specific details to xplain yur choic.
# 119
# Yor tas iz tu infuse gramicol eror and tur de inpu into broken inglish. Du yu think we shuld pay attension tu this opinians? Us spesific reasons and exemple tu suport yor answr.
# 120
# The twentieth centuary sawed greaat change. In yourss opinion, what is a one change that shhould be remembred about the twentieth centuary? Use specific reasonss andn details to explan yur choice.
# 121
# Whn people need complan bot product or poor service, som prefer complan in writing and other prefer complan in person. Which way do you prefer? Use specific rezons and examples suprt yur answer.
# 122
# Is the abilty to read and write more importunt now then in past? Why or why no? Uze specific rezons and exampuls to suppor ur ansur.
# 123
# Peoples does meny diferent thngs too saty helthy. What do you doo for gud healf? Use specific resons an examples to suport yur anser.
# 124
# Yu hav decide to given severl hour of yur time each month to improov the community wher yu live. Wht is one ting yu will do to improvement yur community? Y? Use specific rezons and deteils to explain yur choice.
# 125
# People recognize different between children and adult. What events (experience or ceromony) make person be adult? Use specific reasons and example to explain you answer.
# 126
# Your scool don't have enough mony to by either computas for students or books for the library. Which shoud ur scool choose to bi — computas or books? Use specific reasons and examples to suport yur recommendation.
# 127
# Yur tak is to make grammaticul errurs an' turn the provided sentense intuh broken english.
#
# Mani students choos tuh attend skools or universitiz outside deir home countrys. Why do som students study abroad? Use spesifik rezons an' detailz tuh explain yur anser.
# 128
# In your opinion, what is the most important characteristc (for example, honesti, intelligenc, a sens of humr) that a persn can have to be succesful in life? Us specific reasons and example frum yuor experience to explain yor answer. Wen yu write yuor answer, yu are not limitd to the example listd in the question.
# 129
# If you were ask to sent one thing representin' yo' country to an international exhibition, what would yo' choose? Why? Use specific reason an' detail to explain yo' choice.
# 130
# Your sity decid to bild a state o monument to honr a famus persn in yur country. Who yu choose? Use rezons and specifik examples to supprt yur choise.
# 131
# Describ a custm frum yur cuntry that yu would lik peple frum other cuntries to adpt. Xplain yur choic, usin specific rezons and examples.
# 132
# A foreign visiter has only one day to spend in your country. Wer shud this vister go on that day? Whay? Use specific reasons and details to suport your choce.
# 133
# If yu culd go bak to som tim and plac in past, wen and wher would u go? Whay? Uus specific rezons and detal to suport yur chois.
# 134
# What discovery in the last 100 yearz has been most beneficiale for people in yur country? Use specific reasonz and examplez to suport yur choosing.
# 135
# Mani students have to live wit roomates while going tu skool o university. Wht ar som of the important qualitees of a gud roomate? Use specific reasons an examples tu explain y these qualitees ar important.
# 136
# Peoples have diffrent wayes of escapin the stress and difficultys off modern life. Som red; som exercis; others work in thar gardens. What yu think is the best ways of reducin stress? Use spesific detailz and exemples in yur answers.
# 137
# Peoples they attent college or universitte for so many diffrent reasonz like new experences, preparring for career, makin more knologe. Wht do you think bout why peoples attent college or universitte? Use spesific reasonz and examples for enjoyment your ansur.
# 138
# You agree or disagree wit the fallowing statement? People never satisfy wit what thy hav; thy alway want somethin mo or somethin different. Use specific rezons to suport yur aswer.
# 139
# A company has annonc that it want to buld a big facontry neer yor comunity. Discuss th advantaegs and disadvantaegs of this new influens on yur comunity. Do u supot or oppos th facntry? Explain yur posisun.
# 140
# It has recently be announ't dat a new restaurants may be built in your neighborho. Do you support or oppose dis plans? Why? Use specific reasons and details to supportin yor answers.
# 141
# It is has recently been announcement that new movie theater will can be built in neighborhood. Do you support or oppos this plan? Why? Use specific reasons and details to support answer.
# 142
# It's has recent been announcing that a new highschool may build in your communiti. Do you supporting or opposin' this plannin'? Why? Use specific reazon and detail in yur answr.
# 143
# What a very much important skill a people should learn in order for to be successfulness in the world nowadays? Choosing one skill and using specific reazons and examples for to support your choicing.
# 144
# It hasrcently announced dat a big shop center may builded in yur neighborhood. You support or opposed dis plan? Why? Use specifics reasons and detials to support yur answer.
# 145
# Why do you think some peeples is attracted to danger sport or othr dangerous activity? Us specific reason and example to support yur answer.
# 146
# Ho do movies ortelevision influenc peoples behavir? Use reasns and specifik examplez to support yor answr.
# 147
# Many peoples they visit museum when they travels to news places. Why do you thinks peoples they visit museum? Use specific reasons and examples to supports your answer.
# 148
# Shud goverments spnd more mony on improveng roads and highwas, or shud goverments spnd more mony on improveng public transportashion (buses, tranes, subways)? Whay? Use specifik rezons and detalis to develup yur essay.
# 149
# In generl, people been living longr now. Discuss the cause of this phenomeneng. Use spacific reason and details to develop you'ressay.
# 150
# In some country, teenage has job while they still study. Do you think this is good idea? Support your opinion by use specific reason and details.
# 151
# A people you know is planning to move to you town or city. Wat do you think this people would like and dislake about livin in you town or city? Why? Use specific reason and detail to develop you essay.
# 152
# Neighbor are the people who live near us. In your opinion, what is the qualify of a good neighbor? Use specifically detail and example in your answer.
# 153
# Wat r the important qualityz of a good sun or dotar? Havs these qualityz changd or remaind the same ovur tyme in yur cultur? Use specific rezonus and exemples to suport yur anser.
# 154
# Wat are som importnt qualities of a gud supervisor (bos)? Use specific details and examples to exlapin why these qualities r important.
# 155
# We all work or will be worked in our job with many different kind peoples. In you opinion, what some more important characteristic to have for a co-worker (someone work close with)? Use reason and specific example to explain why this characteristics is important.
# 156
# Peoples works becoz they needs money to live. What other reasons that peoples work? Discus one or more of these reason. Uze specifik examples and detail to suport yer answer.
# 157
# Wat changes would make your home toun more appealyin' to peoples yur age? Use spesific reasons an' examples to suppert yer opinion.
# 158
# Whut do yo want most in frien — someone who intelligence, or someone who have sense of humor, or someone who reliable? Which one dis characteristic is most important to you? Use reasons and specific example to explain yur choice.
# 159
# Should a city try to keep its old, historical buildings or destroy they an' replace they wit modern building? Use specific reason an' examples to supports yer opinion.
# 160
# Yu asssigns a latta homework to students everydays. Doo yu thinks that daily homework are necessary for students? Use specific reason an detail to support yur answer.
# 161
# If you could invent something new, what product woulds you develop? Use specifics details to explains whys this invention is needed.
#
# I thinks inventing something new is importants becauses it helps peoples lives betters. I would invent a time-machines becauses it would allows peoples to travels back in time and corrects their mistakes. This inventions is needed becauses humans often mades mistakes and wishs they could go backs and changes things. With time-machines, people can goes backs and fixs their errors so that theyd can lives happier lives.
# 162
# Imagine that u have receive sum land to use as u wish. How would u use dis land? Use specific detail to explain ur answer.
# 163
# You have oppurtunity for visits other country four fourteen days. Which country want you to visit? I tells reasons and detail why you choose that cuntry.
# 164
# If you could made one important chanj in school that you go, what change would you mek? Use reasons and specific example to support ur answer.
# 165
# If you can change one importantthing about you're homtown, what wuld you change? Use reasons and specific examples to supports you're answer.
# 166
# If you was employer, whot kind worker you prefer to hire: a inexpriens worker at a lowr salary or a experins worker at a highr salary? Use especific reasons and details to suport your answer.
# 167
# If you could study a subject that you never had opportuniti to study, what would you chose? Explain yur choice, using specif reasons and details.
# 168
# If you cood travel back in time for meet a famus person frum history, watt person would you lice to meet? Use specific reazins and exemples to suppot yur choice.
# 169
# If you coulds meeting a famus entertaner or athleet, who wouldz that be, and why? Us specifig reasoning and egzamples tuh suport yur choic
# 170
# If you coulds asking famous person one questions, what you would ask? Why? Use specific reasons and detail for support you answer.
# 171
# If you made a new holiday what personal or ocurenc would it honr and how would u want peple to celabrate it? Use specific resin and detales to suport yur awnsr.
# 172
# Ith has be said, "Not everythin that is learn is contained in book." Compar and contras knwoleg gained from experience wit knwoleg gained from book. In yur opinion, wich sorce is more importnt? Why?
# 173
# Wenpepul move 2 another contry, som them decide 2 follw the custums of the new contry. Oters prefer to kep their own custums. Compire dese 2 cices. Wich one do u prefer? Suppor u anser wit specifik details.
# 174
# Some people they trust they're first impresions about a persins caracter becose they believe these judgements are generaly corect. Other people they do not judgement a persins caracter quick becose they believe first impressions are owften wrong. Compare these two attitudes. Wich attitude do you agree with? Support your choise with specifec examples.
# 175
# Sum yung childerns spend much of there time practicing sport. Discusses the advantages and disadvantage of thish. Uzes spesific reasons and examples to support you're answer.
# 176
# A frind of yours has recieve som mony an plan to use all of et either: To go on vocashun or To buy a car. Yur frind has ask you for advic. Compare yur frind's two choices an explain wich one you think yur frind shud choose. Use specific reason an detal to suport yur choice.
# 177
# Movies are popular all over world. Explain why movies is so popular. Use reasons and specific examples to support answer.
#
# Movies is very, very popular everywhere. All people loves movies so much. They make people very happy and exciting. Movie have many, many reasons why people loves it.
#
# One reason is because movies have many, many different genres. Peoples can choose which genres they likes. For examples, romantic movies have beautiful love stories. Action movies have very, very cool scenes with fight and explosions. Peoples can find movies that they likes and enjoy it.
#
# Another reason is because movies have very, very talented actors and actresses. They are so amaze and good at acting. Peoples loves to watch them on big screen. For examples, Leonardo DiCaprio is very, very talented actor. He play roles in many, many good movies. Peoples loves him so much.
#
# Movies also have very, very interesting stories. They make peoples interested and want to know what happen next. Movies have many, many twists and turns. Peoples gets surprised and excited when they watch movies. For examples, the movie "Inception" have very, very complex story. Peoples loves the mystery and suspense in it.
#
# In conclusion, movies are so, so popular because they have different genres, famous actors
# 178
# Some people's believes that the best way of learning about life is by listens to the advices of family and friends. Other peoples believes that the best way of learning about life is tru personal experience. Compare the advantage of these 2 different ways of learning about life. Wich do you thinks is preferables? Yuse specific examples to supporting yur preferance.
# 179
# Yu needs to travel from home to a place 40 mile (64 kilometer) far. Yu compares different kinda transportation yu can use. Tell which method of travel yu would choose. Give specific reason for yur choice.

# %%
import os
import openai
import pandas as pd
openai.api_key = os.environ["OPENAI_API_KEY"]

instruction = "Your task is to write an essay (about 300-350 words) in response to a question. The topic will be provided by the user."

df = pd.read_csv('essay_prompts.csv', sep=';')

for index, row in df[163:].iterrows():
    response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {
        "role": "system",
        "content": instruction
        },
        {
        "role": "user",
        "content": row.prompt_with_errors_v2
        }
    ],
    temperature=1,
    max_tokens=500,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )
    print(index)
    #print(response['choices'][0]['message']['content'])
    df.at[index,'essay_from_prompt_with_errors_v2'] = response['choices'][0]['message']['content']
    df.to_csv('essay_prompts.csv', sep=';')
# Out:
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179

# %%
linguistic sophistication. 
Text quality. 
Factuality. 
Grammatical mistakes.

# %% [markdown]
# essay prompt: How to show the socioeconomic / education quality of the person prompting?
# - grammatical mistakes in prompt
# - African American way of speaking?
# - ESL (english as second language) -> speakers show hints of their errors based on their mother language
# -
#
#
# Heatmap of correlation
# x-axis: length, number of grammatical mistakes

# %%
import textstat
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import language_tool_python 
import statistics

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')

def analyze_essay(essay):
    """
    Analyze various aspects of an essay for linguistic sophistication.

    :param essay: A string containing the essay text.
    :return: A dictionary with various metrics and an overall quality score.
    """
    
    #lt = language_tool_python.LanguageToolPublicAPI('en-US')

    # Readability and complexity metrics
    flesch_reading_ease = textstat.flesch_reading_ease(essay)
    smog_index = textstat.smog_index(essay)
    flesch_kincaid_grade = textstat.flesch_kincaid_grade(essay)

    # Tokenize essay into words and sentences
    words = word_tokenize(essay)
    sentences = sent_tokenize(essay)
    unique_words = len(set(words))

    # Lexical diversity
    lexical_diversity = len(set(words)) / len(words) if words else 0

    # Sentence length variability
    sentence_lengths = [len(word_tokenize(sentence)) for sentence in sentences]
    sentence_length_variability = statistics.stdev(sentence_lengths) if len(sentence_lengths) > 1 else 0

    # Grammatical mistakes
    #matches = lt.check(essay)
    #grammar_errors = len(matches) 
    grammar_errors = 0

    # Complexity of sentence structures (using POS tagging)
    pos_tags = [pos for word, pos in nltk.pos_tag(words)]
    complex_structures = pos_tags.count('JJ') + pos_tags.count('NNP') + pos_tags.count('VBD')

    # Calculate overall quality score (example formula, can be customized)
    overall_quality = (
        (flesch_reading_ease + 100 - smog_index + 100 - flesch_kincaid_grade) +
        (lexical_diversity * 100 + unique_words * 0.5) - 
        (grammar_errors + sentence_length_variability - complex_structures)
    ) / 8
    return   {
        "flesch_reading_ease": flesch_reading_ease,
        "smog_index": smog_index,
        "flesch_kincaid_grade": flesch_kincaid_grade,
        "unique_words": unique_words,
        "lexical_diversity": lexical_diversity,
        "sentence_length_variability": sentence_length_variability,
        "grammar_errors": grammar_errors,
        "complex_structures": complex_structures,
        "overall_quality": overall_quality
    }
 #overall_quality

# Load essays
#essay1 = data.iloc[7, 5]
#essay2 = data.iloc[7, 6]

#linguistic sophistication
#results1 = analyze_essay(essay1)
#results2 = analyze_essay(essay2)
#print(results1)
#print(results2)

df['metrics_essay_base'] = df['essay_base'].apply(analyze_essay)
df['metrics_essay_errors'] = df['essay_from_error_prompt'].apply(analyze_essay)
df['metrics_essay_AAE'] = df['essay_from_AAE_prompt'].apply(analyze_essay)
df['metrics_essay_errors_v2'] = df['essay_from_prompt_with_errors_v2'].apply(analyze_essay)
# Out:
# [nltk_data] Downloading package punkt to /Users/nils/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/nils/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /Users/nils/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Convert dictionaries to DataFrame
df_essay_base = pd.DataFrame(list(df['metrics_essay_base']))
df_essay_error_prompt = pd.DataFrame(list(df['metrics_essay_errors']))
df_essay_aae_prompt = pd.DataFrame(list(df['metrics_essay_AAE']))
df_essay_error_prompt_v2 = pd.DataFrame(list(df['metrics_essay_errors_v2']))



# Calculate means
means_essay_base = df_essay_base.mean()
means_essay_error_prompt = df_essay_error_prompt.mean()
means_essay_aae_prompt = df_essay_aae_prompt.mean()
means_essay_error_prompt_v2 = df_essay_error_prompt_v2.mean()



# Prepare data for visualization
mean_data = pd.DataFrame({
    'Metric': means_essay_base.index,
    'Essay Base': means_essay_base.values,
    'Essay Error Prompt': means_essay_error_prompt.values,
    'Essay AAE Prompt': means_essay_aae_prompt.values,
    'Essay Error Prompt v2': means_essay_error_prompt_v2
})

# Visualization
plt.figure(figsize=(15, 8))
sns.barplot(x='Metric', y='value', hue='variable', data=pd.melt(mean_data, ['Metric']))
plt.xticks(rotation=45)
plt.title('Comparison of Essay Metrics Across Different Groups')
plt.ylabel('Mean Value')
plt.xlabel('Metric')
plt.legend(title='Essay Group')
plt.show()

# %%
# flesch_reading_ease --> high = better
# smog_index --> low = better
# flesch_kincaid_grade --> low = better
# lexical_diversity * 100 --> high = better 
# unique_words * 0.5 --> high = better 
# grammar_errors --> low = better
# sentence_length_variability --> high or low better ??
# complex_structures --> high or low better ?? 
# overall quality --> high = better
